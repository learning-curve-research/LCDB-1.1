# %% [markdown]
# ### LCDB 1.1 demo

# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
from pathlib import Path
import os
import warnings
warnings.filterwarnings('ignore')
import sys
sys.path.append(os.path.join(os.getcwd(), '../analysis/'))
from meta_feature import dataset_ids_CC18, dataset_ids_FULL, anchor_list_denser, learner_zoo

# %% [markdown]
# ### Error Rate Learning Curves

# %%
# OpenML dataset ID
dataset_ids = dataset_ids_CC18
# Learner name
learner_zoo = learner_zoo
# anchor
anchor_list = anchor_list_denser

# load the data
with h5py.File(Path.cwd() / 'LCDB11_ER_CC18_24.hdf5', 'r') as f:
    dataset = f['error rate'][...]
print(f'Database shape: {dataset.shape}')
print('(dataset, learner, outer split, inner split, anchor, train-val-test, noFS-mixmaxFS-standardFS, raw-clean)')
# Out:
# Database shape: (72, 24, 5, 5, 137, 3, 3, 2)
# (dataset, learner, outer split, inner split, anchor, train-val-test, noFS-mixmaxFS-standardFS, raw-clean)

# %%
dataset_index, learner_index, outer_split, inner_split, feature_scaling, data_acquisition = 0, 6, 0, 0, 0, 0

plt.figure()
plt.plot(anchor_list, dataset[dataset_index, learner_index, outer_split, inner_split,:, 0, feature_scaling, data_acquisition], label="Training")
plt.plot(anchor_list, dataset[dataset_index, learner_index, outer_split, inner_split,:, 1, feature_scaling, data_acquisition], label="Validataion")
plt.plot(anchor_list, dataset[dataset_index, learner_index, outer_split, inner_split,:, 2, feature_scaling, data_acquisition], label="Testing")
plt.title(f'Learner {learner_zoo[learner_index]}, OpenML ID {dataset_ids[dataset_index]}')
plt.xlabel('Training Set Size')
plt.ylabel('Error Rate')
plt.legend()
plt.show()

# %%
dataset_index, learner_index, train_val_test, feature_scaling, data_acquisition = 0, 6, 1, 0, 0

plt.figure(figsize=(6, 5))
mean_curve = np.nanmean(dataset[dataset_index, learner_index, :, :, :, train_val_test, feature_scaling, data_acquisition], axis=(0, 1))
std_curve = np.nanstd(dataset[dataset_index, learner_index, :, :, :, train_val_test, feature_scaling, data_acquisition], axis=(0, 1))
plt.plot(anchor_list, mean_curve, label='Validation')
plt.fill_between(anchor_list, mean_curve - std_curve, mean_curve + std_curve, alpha=0.2)
plt.title(f'Learner {learner_zoo[learner_index]}, OpenML ID {dataset_ids[dataset_index]}')
plt.xlabel('Training Set Size')
plt.ylabel('Error Rate')
plt.legend()
plt.show()

# %% [markdown]
# ### Other metrics

# %%
# OpenML dataset ID
dataset_ids = dataset_ids_FULL
# Learner name
learner_zoo = learner_zoo
# anchor
anchor_list = anchor_list_denser

# load the data
with h5py.File(Path.cwd() / 'LCDB11_AUC_265_24.hdf5', 'r') as f:
    dataset = f['AUC'][...]
print(f'Database shape: {dataset.shape}')
print('(dataset, learner, outer split, inner split, anchor, train-val-test, noFS-mixmaxFS-standardFS, raw-clean)')

dataset_index, learner_index, train_val_test, feature_scaling, data_acquisition = 0, 6, 1, 0, 0

plt.figure(figsize=(6, 5))
mean_curve = np.nanmean(dataset[dataset_index, learner_index, :, :, :, train_val_test, feature_scaling, data_acquisition], axis=(0, 1))
std_curve = np.nanstd(dataset[dataset_index, learner_index, :, :, :, train_val_test, feature_scaling, data_acquisition], axis=(0, 1))
plt.plot(anchor_list, mean_curve, label='Validation')
plt.fill_between(anchor_list, mean_curve - std_curve, mean_curve + std_curve, alpha=0.2)
plt.title(f'Learner {learner_zoo[learner_index]}, OpenML ID {dataset_ids[dataset_index]}')
plt.xlabel('Training Set Size')
plt.ylabel('AUC (OvR)')
plt.legend()
plt.show()
# Out:
# Database shape: (265, 24, 5, 5, 137, 3, 3, 2)
# (dataset, learner, outer split, inner split, anchor, train-val-test, noFS-mixmaxFS-standardFS, raw-clean)

# %%
# OpenML dataset ID
dataset_ids = dataset_ids_FULL
# Learner name
learner_zoo = learner_zoo
# anchor
anchor_list = anchor_list_denser

# load the data
with h5py.File(Path.cwd() / 'LCDB11_log-loss_265_24.hdf5', 'r') as f:
    dataset = f['log-loss'][...]
print(f'Database shape: {dataset.shape}')
print('(dataset, learner, outer split, inner split, anchor, train-val-test, noFS-mixmaxFS-standardFS, raw-clean)')

dataset_index, learner_index, train_val_test, feature_scaling, data_acquisition = 0, 6, 1, 0, 0

plt.figure(figsize=(6, 5))
mean_curve = np.nanmean(dataset[dataset_index, learner_index, :, :, :, train_val_test, feature_scaling, data_acquisition], axis=(0, 1))
std_curve = np.nanstd(dataset[dataset_index, learner_index, :, :, :, train_val_test, feature_scaling, data_acquisition], axis=(0, 1))
plt.plot(anchor_list, mean_curve, label='Validation')
plt.fill_between(anchor_list, mean_curve - std_curve, mean_curve + std_curve, alpha=0.2)
plt.title(f'Learner {learner_zoo[learner_index]}, OpenML ID {dataset_ids[dataset_index]}')
plt.xlabel('Training Set Size')
plt.ylabel('Log-Loss')
plt.legend()
plt.show()
# Out:
# Database shape: (265, 24, 5, 5, 137, 3, 3, 2)
# (dataset, learner, outer split, inner split, anchor, train-val-test, noFS-mixmaxFS-standardFS, raw-clean)

# %%
# OpenML dataset ID
dataset_ids = dataset_ids_FULL
# Learner name
learner_zoo = learner_zoo
# anchor
anchor_list = anchor_list_denser

# load the data
with h5py.File(Path.cwd() / 'LCDB11_f1_265_24.hdf5', 'r') as f:
    dataset = f['f1'][...]
print(f'Database shape: {dataset.shape}')
print('(dataset, learner, outer split, inner split, anchor, train-val-test, noFS-mixmaxFS-standardFS, raw-clean)')

dataset_index, learner_index, train_val_test, feature_scaling, data_acquisition = 0, 6, 1, 0, 0

plt.figure(figsize=(6, 5))
mean_curve = np.nanmean(dataset[dataset_index, learner_index, :, :, :, train_val_test, feature_scaling, data_acquisition], axis=(0, 1))
std_curve = np.nanstd(dataset[dataset_index, learner_index, :, :, :, train_val_test, feature_scaling, data_acquisition], axis=(0, 1))
plt.plot(anchor_list, mean_curve, label='Validation')
plt.fill_between(anchor_list, mean_curve - std_curve, mean_curve + std_curve, alpha=0.2)
plt.title(f'Learner {learner_zoo[learner_index]}, OpenML ID {dataset_ids[dataset_index]}')
plt.xlabel('Training Set Size')
plt.ylabel('F1')
plt.legend()
plt.show()
# Out:
# Database shape: (265, 24, 5, 5, 137, 3, 3, 2)
# (dataset, learner, outer split, inner split, anchor, train-val-test, noFS-mixmaxFS-standardFS, raw-clean)

# %%
# OpenML dataset ID
dataset_ids = dataset_ids_FULL
# Learner name
learner_zoo = learner_zoo
# anchor
anchor_list = anchor_list_denser

# load the data
with h5py.File(Path.cwd() / 'LCDB11_traintime_265_24.hdf5', 'r') as f:
    dataset = f['traintime'][...]
print(f'Database shape: {dataset.shape}')
print('(dataset, learner, outer split, inner split, anchor, noFS-mixmaxFS-standardFS, raw-clean)')

dataset_index, learner_index, feature_scaling, data_acquisition = 0, 6, 0, 0

plt.figure(figsize=(6, 5))
mean_curve = np.nanmean(dataset[dataset_index, learner_index, :, :, :, feature_scaling, data_acquisition], axis=(0, 1))
std_curve = np.nanstd(dataset[dataset_index, learner_index, :, :, :, feature_scaling, data_acquisition], axis=(0, 1))
plt.plot(anchor_list, mean_curve, label='Validation')
plt.fill_between(anchor_list, mean_curve - std_curve, mean_curve + std_curve, alpha=0.2)
plt.title(f'Learner {learner_zoo[learner_index]}, OpenML ID {dataset_ids[dataset_index]}')
plt.xlabel('Training Set Size')
plt.ylabel('Training Time')
plt.legend()
plt.show()
# Out:
# Database shape: (265, 24, 5, 5, 137, 3, 2)
# (dataset, learner, outer split, inner split, anchor, noFS-mixmaxFS-standardFS, raw-clean)

# %% [markdown]
# ### Error Message in Error Rate Learning Curves

# %%
# OpenML dataset ID
dataset_ids = dataset_ids_FULL
# Learner name
learner_zoo = learner_zoo
# anchor
anchor_list = anchor_list_denser

status_dic = {0: "ok", 1: "timeout", 2: "error"}

# load the data
with h5py.File(Path.cwd() / 'LCDB11_msg_265_24.hdf5', 'r') as f:
    status_dataset = f['status'][...]
print(f'Database shape: {status_dataset.shape}')
print('(dataset, learner, outer split, inner split, anchor, noFS-mixmaxFS-standardFS, raw-clean)')
print(f'Dictionary: {status_dic}')
# Out:
# Database shape: (265, 24, 5, 5, 137, 3, 2)
# (dataset, learner, outer split, inner split, anchor, noFS-mixmaxFS-standardFS, raw-clean)
# Dictionary: {0: 'ok', 1: 'timeout', 2: 'error'}

# %%
dataset_index, outer_split, inner_split, anchor_index, feature_scaling, data_acquisition = 0, 0, 0, 0, 2, 0
print("We load the standardization feature scaling version with inner and outer seed as zero. ")
print("check first anchor: ")
status_slice = status_dataset[dataset_index, :, outer_split, inner_split, anchor_index, feature_scaling, data_acquisition]
status_readable = {learner_zoo[i]: status_dic[status] for i, status in enumerate(status_slice)}

for learner, status in status_readable.items():
    print(f"Openml dataset ID: {dataset_ids_FULL[dataset_index]}, learner: {learner}, status: {status}")
# Out:
# We load the standardization feature scaling version with inner and outer seed as zero.
# check first anchor:
# Openml dataset ID: 3, learner: SVM_Linear, status: ok
# Openml dataset ID: 3, learner: SVM_Poly, status: ok
# Openml dataset ID: 3, learner: SVM_RBF, status: ok
# Openml dataset ID: 3, learner: SVM_Sigmoid, status: ok
# Openml dataset ID: 3, learner: Decision Tree, status: ok
# Openml dataset ID: 3, learner: ExtraTree, status: ok
# Openml dataset ID: 3, learner: LogisticRegression, status: ok
# Openml dataset ID: 3, learner: PassiveAggressive, status: ok
# Openml dataset ID: 3, learner: Perceptron, status: ok
# Openml dataset ID: 3, learner: RidgeClassifier, status: ok
# Openml dataset ID: 3, learner: SGDClassifier, status: ok
# Openml dataset ID: 3, learner: MLP, status: ok
# Openml dataset ID: 3, learner: LDA, status: ok
# Openml dataset ID: 3, learner: QDA, status: ok
# Openml dataset ID: 3, learner: BernoulliNB, status: ok
# Openml dataset ID: 3, learner: MultinomialNB, status: error
# Openml dataset ID: 3, learner: ComplementNB, status: error
# Openml dataset ID: 3, learner: GaussianNB, status: ok
# Openml dataset ID: 3, learner: KNN, status: ok
# Openml dataset ID: 3, learner: NearestCentroid, status: ok
# Openml dataset ID: 3, learner: ens.ExtraTrees, status: ok
# Openml dataset ID: 3, learner: ens.RandomForest, status: ok
# Openml dataset ID: 3, learner: ens.GradientBoosting, status: ok
# Openml dataset ID: 3, learner: DummyClassifier, status: ok

# %% [markdown]
# Then we load error message dataset to check the reason

# %%
learner_index = 16
with h5py.File(Path.cwd() / 'LCDB11_msg_265_24.hdf5', 'r') as f:
    msg_dataset = f['error message'][dataset_index, learner_index, outer_split, inner_split, anchor_index, feature_scaling, data_acquisition]

print(f'Error message of learner {learner_zoo[learner_index]}: {msg_dataset.decode('utf-8')}')
# Out:
# Error message of learner ComplementNB: Negative values in data passed to ComplementNB (input X)
